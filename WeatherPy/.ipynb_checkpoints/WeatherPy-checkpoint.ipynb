# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress

os.chdir("../")   # change directory to import a shared output directory and API Key 

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
from pprint import pprint

# Output File (CSV)
output_data_file = "Weatherpy/output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding for holding respective information
lat_lngs = []
cities = []
latlist =[]
lnglist =[]
maxTemps = []
humidity = []
cloudiness = []
windSpeeds = []
countries = []
dates = []
city = []    

baseURL = "https://api.openweathermap.org/data/2.5/weather?"  # base URL for weatherAPI
units = 'imperial'       # Units for displaying weather in fahrenheit

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

citiesToProcess = pd.DataFrame (cities, columns = ['City'])

#setup the remaining columns 
citiesToProcess["Lat"]="" 
citiesToProcess["Lng"]="" 
citiesToProcess["Max Temp"]="" 
citiesToProcess["Humidity"]="" 
citiesToProcess["Cloudiness"]="" 
citiesToProcess["Wind Speed"]="" 
citiesToProcess["Country"]="" 
citiesToProcess["Date"]="" 
citiesToProcess.head()
# Out:
#              City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country Date
# 0        hermanus
# 1  cap-aux-meules
# 2        paracuru
# 3         ushuaia
# 4       kavaratti

# %%
len(cities) # the length of expected items
# Out:
# 603

# %%
citiesToProcess.head()
# Out:
#              City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country Date
# 0        hermanus
# 1  cap-aux-meules
# 2        paracuru
# 3         ushuaia
# 4       kavaratti

# %% [markdown]
# ### Perform API Calls
# Process cities that are betwen latitude and longitude range

# %%
 # setup parameters for passing to API to generate URL based on respective city passed into URL
baseURL = "https://api.openweathermap.org/data/2.5/weather?"
units="imperial"

parameters = {
      "units":units,
     "appid":weather_api_key,
}
group = 1
recordCount = 1

print (f"Beginning Data Retrieval ")
print (f"------------------------ ")
for index, row in citiesToProcess.iterrows():
    #print(index)
    if recordCount <= 50 :
        parameters['q'] = citiesToProcess.loc[index,'City']
    
        print (f"Processing Record {recordCount} of Set  {group} | {citiesToProcess.loc[index,'City']} ")
        getCityData = requests.get(baseURL,params=parameters).json()

        try:
            #grab infomration from results key 
            citiesToProcess.loc[index,'City']=getCityData['name']
            citiesToProcess.loc[index,'Lat']=getCityData['coord']['lat']
            citiesToProcess.loc[index,'Lng']=getCityData['coord']['lon']
            citiesToProcess.loc[index,'Max Temp']=getCityData['main']['temp_max']
            citiesToProcess.loc[index,'Humidity']=getCityData['main']['humidity']
            citiesToProcess.loc[index,'Cloudiness']=getCityData['clouds']['all']
            citiesToProcess.loc[index,'Wind Speed']=getCityData['wind']['speed']
            citiesToProcess.loc[index,'Country']=getCityData['sys']['country']
            citiesToProcess.loc[index,'Date']=getCityData['dt']
            
            recordCount +=1   # control count for the conditional 
            time.sleep(2)   # pause between number of records processed

        except (KeyError,IndexError):
            print("City not found. Skipping...")
    else:
        recordCount  = 1
        group += 1
        
            

    #Processing Record 1 of Set 1 | butaritari
    
print (f"------------------------ ")
print (f"Data Retrieval Complete ")
print (f"------------------------ ")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of
# Processing Record 9 of Set  5 | igurubi
# Processing Record 10 of Set  5 | bol
# Processing Record 11 of Set  5 | longyearbyen
# Processing Record 12 of Set  5 | dukat
# Processing Record 13 of Set  5 | vuktyl
# Processing Record 14 of Set  5 | faanui
# Processing Record 15 of Set  5 | ruteng
# Processing Record 16 of Set  5 | dauphin
# Processing Record 17 of Set  5 | hailey
# Processing Record 18 of Set  5 | lebu
# Processing Record 19 of Set  5 | hami
# Processing Record 20 of Set  5 | mogadishu
# Processing Record 21 of Set  5 | huanren
# Processing Record 22 of Set  5 | xinzhou
# Processing Record 23 of Set  5 | teplodar
# Processing Record 24 of Set  5 | kichera
# Processing Record 25 of Set  5 | amurzet
# Processing Record 26 of Set  5 | nizwa
# Processing Record 27 of Set  5 | la ronge
# Processing Record 28 of Set  5 | alofi
# Processing Record 29 of Set  5 | cherskiy
# Processing Record 30 of Set  5 | pangnirtung
# Processing Record 31 of Set  5 | astaneh-ye ashrafiyeh
# Processing Record 32 of Set  5 | camana
# Processing Record 33 of Set  5 | port shepstone
# Processing Record 34 of Set  5 | berdyuzhye
# City not found. Skipping...
# Processing Record 34 of Set  5 | ponta do sol
# Processing Record 35 of Set  5 | guerrero negro
# Processing Record 36 of Set  5 | zhelnino
# City not found. Skipping...
# Processing Record 36 of Set  5 | hermon
# Processing Record 37 of Set  5 | paine
# Processing Record 38 of Set  5 | husavik
# Processing Record 39 of Set  5 | hunza
# City not found. Skipping...
# Processing Record 39 of Set  5 | fort nelson
# Processing Record 40 of Set  5 | luderitz
# Processing Record 41 of Set  5 | qostanay
# Processing Record 42 of Set  5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set  5 | avera
# Processing Record 43 of Set  5 | poya
# Processing Record 44 of Set  5 | santa isabel
# Processing Record 45 of Set  5 | taoudenni
# Processing Record 46 of Set  5 | south lake tahoe
# Processing Record 47 of Set  5 | bar harbor
# Processing Record 48 of Set  5 | north bend
# Processing Record 49 of Set  5 | mana
# Processing Record 50 of Set  5 | asfi
# Processing Record 1 of Set  6 | bandundu
# Processing Record 2 of Set  6 | melilla
# Processing Record 3 of Set  6 | khandbari
# Processing Record 4 of Set  6 | matagami
# Processing Record 5 of Set  6 | bambous virieux
# Processing Record 6 of Set  6 | yangjiang
# Processing Record 7 of Set  6 | iqaluit
# Processing Record 8 of Set  6 | rujewa
# Processing Record 9 of Set  6 | hun
# Processing Record 10 of Set  6 | key west
# Processing Record 11 of Set  6 | meulaboh
# Processing Record 12 of Set  6 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set  6 | vila
# Processing Record 13 of Set  6 | les cayes
# Processing Record 14 of Set  6 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set  6 | narsaq
# Processing Record 15 of Set  6 | saint-philippe
# Processing Record 16 of Set  6 | basoko
# Processing Record 17 of Set  6 | sangar
# Processing Record 18 of Set  6 | borogontsy
# Processing Record 19 of Set  6 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set  6 | ust-ishim
# Processing Record 20 of Set  6 | verkhnyaya inta
# Processing Record 21 of Set  6 | lerwick
# Processing Record 22 of Set  6 | baft
# Processing Record 23 of Set  6 | hoa binh
# Processing Record 24 of Set  6 | northam
# Processing Record 25 of Set  6 | miranorte
# City not found. Skipping...
# Processing Record 25 of Set  6 | nanortalik
# Processing Record 26 of Set  6 | noumea
# Processing Record 27 of Set  6 | toliary
# City not found. Skipping...
# Processing Record 27 of Set  6 | aflu
# City not found. Skipping...
# Processing Record 27 of Set  6 | barrow
# Processing Record 28 of Set  6 | college
# Processing Record 29 of Set  6 | the valley
# Processing Record 30 of Set  6 | luanda
# Processing Record 31 of Set  6 | manjakandriana
# Processing Record 32 of Set  6 | half moon bay
# Processing Record 33 of Set  6 | hamilton
# Processing Record 34 of Set  6 | standerton
# Processing Record 35 of Set  6 | pankovka
# Processing Record 36 of Set  6 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set  6 | fortuna
# Processing Record 37 of Set  6 | forestville
# Processing Record 38 of Set  6 | mount isa
# Processing Record 39 of Set  6 | inta
# Processing Record 40 of Set  6 | sinnamary
# Processing Record 41 of Set  6 | ceres
# Processing Record 42 of Set  6 | lodja
# Processing Record 43 of Set  6 | beira
# Processing Record 44 of Set  6 | parava
# Processing Record 45 of Set  6 | rio gallegos
# Processing Record 46 of Set  6 | gzhatsk
# City not found. Skipping...
# Processing Record 46 of Set  6 | kahului
# Processing Record 47 of Set  6 | sines
# Processing Record 48 of Set  6 | venice
# Processing Record 49 of Set  6 | bilibino
# Processing Record 50 of Set  6 | kamien pomorski
# Processing Record 1 of Set  7 | tilichiki
# Processing Record 2 of Set  7 | shingu
# Processing Record 3 of Set  7 | chumikan
# Processing Record 4 of Set  7 | menongue
# Processing Record 5 of Set  7 | nizhniy tsasuchey
# Processing Record 6 of Set  7 | mora
# Processing Record 7 of Set  7 | cartagena del chaira
# Processing Record 8 of Set  7 | maniitsoq
# Processing Record 9 of Set  7 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set  7 | adrar
# Processing Record 10 of Set  7 | koungou
# Processing Record 11 of Set  7 | kawalu
# Processing Record 12 of Set  7 | vardo
# Processing Record 13 of Set  7 | ilulissat
# Processing Record 14 of Set  7 | kysyl-syr
# Processing Record 15 of Set  7 | sisimiut
# Processing Record 16 of Set  7 | tornio
# Processing Record 17 of Set  7 | doba
# Processing Record 18 of Set  7 | nemuro
# Processing Record 19 of Set  7 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set  7 | bafang
# Processing Record 20 of Set  7 | irbit
# Processing Record 21 of Set  7 | haapiti
# Processing Record 22 of Set  7 | padang
# Processing Record 23 of Set  7 | tingi
# Processing Record 24 of Set  7 | voi
# Processing Record 25 of Set  7 | lundazi
# Processing Record 26 of Set  7 | coquimbo
# Processing Record 27 of Set  7 | fonte boa
# Processing Record 28 of Set  7 | huangcun
# Processing Record 29 of Set  7 | port macquarie
# Processing Record 30 of Set  7 | vostok
# Processing Record 31 of Set  7 | morogoro
# Processing Record 32 of Set  7 | sakakah
# Processing Record 33 of Set  7 | monte alegre
# Processing Record 34 of Set  7 | kemerovo
# Processing Record 35 of Set  7 | shamary
# Processing Record 36 of Set  7 | nenjiang
# Processing Record 37 of Set  7 | olafsvik
# Processing Record 38 of Set  7 | saint pete beach
# Processing Record 39 of Set  7 | never
# Processing Record 40 of Set  7 | kismayo
# Processing Record 41 of Set  7 | tongchuan
# Processing Record 42 of Set  7 | haines junction
# Processing Record 43 of Set  7 | caucaia
| tapaua
# City not found. Skipping...
# Processing Record 10 of Set  9 | bollnas
# Processing Record 11 of Set  9 | spornoye
# Processing Record 12 of Set  9 | choya
# Processing Record 13 of Set  9 | grindavik
# Processing Record 14 of Set  9 | borinskoye
# Processing Record 15 of Set  9 | matara
# Processing Record 16 of Set  9 | wad rawah
# Processing Record 17 of Set  9 | zima
# Processing Record 18 of Set  9 | adet
# Processing Record 19 of Set  9 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set  9 | lagoa
# Processing Record 20 of Set  9 | bonito
# Processing Record 21 of Set  9 | bolshaya murta
# City not found. Skipping...
# Processing Record 21 of Set  9 | grand-santi
# Processing Record 22 of Set  9 | itambacuri
# Processing Record 23 of Set  9 | urdoma
# Processing Record 24 of Set  9 | goderich
# Processing Record 25 of Set  9 | rauma
# Processing Record 26 of Set  9 | catuday
# Processing Record 27 of Set  9 | fuyu
# Processing Record 28 of Set  9 | muros
# Processing Record 29 of Set  9 | kampot
# Processing Record 30 of Set  9 | ler
# Processing Record 31 of Set  9 | maarianhamina
# Processing Record 32 of Set  9 | namibe
# Processing Record 33 of Set  9 | berlevag
# Processing Record 34 of Set  9 | leh
# Processing Record 35 of Set  9 | ilfracombe
# Processing Record 36 of Set  9 | rawatbhata
# Processing Record 37 of Set  9 | morgan city
# Processing Record 38 of Set  9 | rafsanjan
# Processing Record 39 of Set  9 | marechal candido rondon
# Processing Record 40 of Set  9 | katsuura
# Processing Record 41 of Set  9 | poyarkovo
# Processing Record 42 of Set  9 | logumkloster
# Processing Record 43 of Set  9 | mareeba
# Processing Record 44 of Set  9 | singapore
# Processing Record 45 of Set  9 | umm durman
# City not found. Skipping...
# Processing Record 45 of Set  9 | hovd
# Processing Record 46 of Set  9 | manokwari
# Processing Record 47 of Set  9 | alice springs
# Processing Record 48 of Set  9 | aubenas
# Processing Record 49 of Set  9 | gaoual
# Processing Record 50 of Set  9 | touros
# Processing Record 1 of Set  10 | asilah
# Processing Record 2 of Set  10 | jawhar
# Processing Record 3 of Set  10 | neuquen
# Processing Record 4 of Set  10 | gopalpur
# Processing Record 5 of Set  10 | biscarrosse
# Processing Record 6 of Set  10 | colwyn bay
# Processing Record 7 of Set  10 | wana
# Processing Record 8 of Set  10 | borovskoy
# Processing Record 9 of Set  10 | sharlyk
# Processing Record 10 of Set  10 | la palma
# Processing Record 11 of Set  10 | road town
# Processing Record 12 of Set  10 | kapuskasing
# Processing Record 13 of Set  10 | harper
# Processing Record 14 of Set  10 | tahta
# Processing Record 15 of Set  10 | marsh harbour
# Processing Record 16 of Set  10 | antalaha
# Processing Record 17 of Set  10 | huilong
# Processing Record 18 of Set  10 | plettenberg bay
# Processing Record 19 of Set  10 | borgo san lorenzo
# Processing Record 20 of Set  10 | nome
# Processing Record 21 of Set  10 | anadyr
# Processing Record 22 of Set  10 | pascagoula
# Processing Record 23 of Set  10 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set  10 | honiara
# Processing Record 24 of Set  10 | antofagasta
# Processing Record 25 of Set  10 | shchelyayur
# City not found. Skipping...
# Processing Record 25 of Set  10 | kangaatsiaq
# Processing Record 26 of Set  10 | itoman
# Processing Record 27 of Set  10 | tambura
# Processing Record 28 of Set  10 | san quintin
# Processing Record 29 of Set  10 | luyang
# Processing Record 30 of Set  10 | opelousas
# Processing Record 31 of Set  10 | soavinandriana
# Processing Record 32 of Set  10 | pismo beach
# Processing Record 33 of Set  10 | okha
# Processing Record 34 of Set  10 | okhotsk
# Processing Record 35 of Set  10 | vila franca do campo
# Processing Record 36 of Set  10 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set  10 | campbell river
# Processing Record 37 of Set  10 | saint-augustin
# Processing Record 38 of Set  10 | banjar
# Processing Record 39 of Set  10 | cayenne
# Processing Record 40 of Set  10 | srednekolymsk
# Processing Record 41 of Set  10 | bousse
# Processing Record 42 of Set  10 | andili
# Processing Record 43 of Set  10 | kampong thum
# Processing Record 44 of Set  10 | koslan
# Processing Record 45 of Set  10 | rundu
# Processing Record 46 of Set  10 | emba
# Processing Record 47 of Set  10 | russell
# Processing Record 48 of Set  10 | macaboboni
# City not found. Skipping...
# Processing Record 48 of Set  10 | rolim de moura
# City not found. Skipping...
# Processing Record 48 of Set  10 | deputatskiy
# Processing Record 49 of Set  10 | murdochville
# Processing Record 50 of Set  10 | waiouru
# Processing Record 1 of Set  11 | oranjestad
# Processing Record 2 of Set  11 | havre-saint-pierre
# Processing Record 3 of Set  11 | seoul
# Processing Record 4 of Set  11 | darnah
# Processing Record 5 of Set  11 | marathon
# Processing Record 6 of Set  11 | qianguo
# Processing Record 7 of Set  11 | dakoro
# Processing Record 8 of Set  11 | tual
# Processing Record 9 of Set  11 | freeport
# Processing Record 10 of Set  11 | ouadda
# Processing Record 11 of Set  11 | cradock
# Processing Record 12 of Set  11 | bayeux
# Processing Record 13 of Set  11 | kawana waters
# City not found. Skipping...
# Processing Record 13 of Set  11 | hay river
# Processing Record 14 of Set  11 | baykit
# Processing Record 15 of Set  11 | saint-louis
# Processing Record 16 of Set  11 | port hueneme
# Processing Record 17 of Set  11 | hakui
# Processing Record 18 of Set  11 | mangla
# Processing Record 19 of Set  11 | la ciotat
# Processing Record 20 of Set  11 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set  11 | kuala sungai baru
# Processing Record 21 of Set  11 | mindelo
# Processing Record 22 of Set  11 | agirish
# Processing Record 23 of Set  11 | hualmay
# Processing Record 24 of Set  11 | litoral del san juan
# City not found. Skipping...
# Processing Record 24 of Set  11 | mizdah
# Processing Record 25 of Set  11 | richards bay
# Processing Record 26 of Set  11 | lander
# Processing Record 27 of Set  11 | chihuahua
# Processing Record 28 of Set  11 | altay
# Processing Record 29 of Set  11 | grand gaube
# Processing Record 30 of Set  11 | hudson bay
# Processing Record 31 of Set  11 | bathsheba
# Processing Record 32 of Set  11 | hirara
# Processing Record 33 of Set  11 | yerbogachen
# Processing Record 34 of Set  11 | hirado
# Processing Record 35 of Set  11 | cairns
# Processing Record 36 of Set  11 | curumani
# Processing Record 37 of Set  11 | woodward
# Processing Record 38 of Set  11 | egvekinot
# Processing Record 39 of Set  11 | jasper
# Processing Record 40 of Set  11 | opuwo
# Processing Record 41 of Set  11 | kieta
# Processing Record 42 of Set  11 | kenai
# Processing Record 43 of Set  11 | yoichi
# ------------------------
# Data Retrieval Complete
# ------------------------

# %%
# Export to CSV 
citiesToProcess.to_csv(output_data_file)

# %%
# convert to a dataframe for future Processing
citiesDataDF=pd.DataFrame(citiesToProcess)
citiesDataDF.head()
# Out:
#              City      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0        Hermanus -34.4187  19.2345     51.8       79         82      15.19
# 1  Cap-aux-Meules  47.3821 -61.8597    66.25       88         75       9.22
# 2        Paracuru    -3.41 -39.0306    75.11       80         11      13.98
# 3         Ushuaia    -54.8    -68.3    35.26       93        100       6.91
# 4       Kavaratti  10.5669   72.642    81.63       78        100      10.29
#
#   Country        Date
# 0      ZA  1660454723
# 1      CA  1660454725
# 2      BR  1660454728
# 3      AR  1660454441
# 4      IN  1660454732

# %%
# convert columns to numeric datatype to gather statistics
citiesDataDF[['Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']] = citiesDataDF[['Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']].apply(pd.to_numeric)
print(citiesDataDF.dtypes)
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity      float64
# Cloudiness    float64
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %%
citiesDataDF.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  543.000000  543.000000  543.000000  543.000000  543.000000  543.000000
# mean    19.830385   16.458527   69.148343   69.438306   56.029466    7.735764
# std     33.772123   90.570775   13.413203   20.830616   38.906206    5.307975
# min    -54.800000 -179.166700   33.820000    1.000000    0.000000    0.000000
# 25%     -8.768400  -63.677700   59.645000   56.000000   17.000000    3.670000
# 50%     24.800000   22.400700   70.300000   73.000000   68.000000    6.870000
# 75%     48.702700   99.717700   79.095000   85.000000   97.000000   10.445000
# max     78.218600  178.416700  101.820000  100.000000  100.000000   33.170000

# %%
#  Get the indices of cities that have humidity over 100%.
hudmidityOver100 =citiesDataDF[(citiesDataDF['Humidity'] > 100)].index
print (hudmidityOver100)
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data
clean_city_data = citiesDataDF.drop(hudmidityOver100, inplace=False)
clean_city_data.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hermanus -34.4187  19.2345     51.80      79.0        82.0
# 1  Cap-aux-Meules  47.3821 -61.8597     66.25      88.0        75.0
# 2        Paracuru  -3.4100 -39.0306     75.11      80.0        11.0
# 3         Ushuaia -54.8000 -68.3000     35.26      93.0       100.0
# 4       Kavaratti  10.5669  72.6420     81.63      78.0       100.0
#
#    Wind Speed Country        Date
# 0       15.19      ZA  1660454723
# 1        9.22      CA  1660454725
# 2       13.98      BR  1660454728
# 3        6.91      AR  1660454441
# 4       10.29      IN  1660454732

# %%
# extract data from dataframe into CSV file 
lat = clean_city_data["Lat"]
lng = clean_city_data["Lng"]
MaxTemp= clean_city_data["Max Temp"]
Humidity = clean_city_data["Humidity"]
Cloudiness = clean_city_data["Cloudiness"]
WindSpeed = clean_city_data["Wind Speed"]

clean_city_data.to_csv(output_data_file, index_label="CityID")

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lat, MaxTemp,edgecolors="black", linewidths=1,marker="o", alpha=0.8, label = "Cities")
plt.title("City Latitude vs Max Tempertature (%s)" % time.strftime("%x")) # add current data to chart
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

#Save graph as a png
plt.savefig("Weatherpy/output_data/city_latitude_vs_temp.png")

#show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lat, Humidity,edgecolors="black", linewidths=1,marker="o", alpha=0.8, label = "Cities")
plt.title("City Latitude vs Humidity (%s)" % time.strftime("%x")) # add current data to chart
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

#Save graph as a png
plt.savefig("Weatherpy/output_data/city_latitude_vs_humidity.png")

#show plot
plt.show()

# %% [markdown]
# This day it was observed that the humditity is high closer to the equatoer there does not appear to be any correction between
# the latitude and the humditiy.  Looking at the latitude between -40 and 60  there are a lot of cities with humdidity near 100.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, Cloudiness,edgecolors="black", linewidths=1,marker="o", alpha=0.8, label = "Cities")
plt.title("City Latitude vs Cloudiness (%s)" % time.strftime("%x")) # add current data to chart
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

#Save graph as a png
plt.savefig("Weatherpy/output_data/city_latitude_vs_cloudiness.png")

#show plot
plt.show()

# %% [markdown]
# There is no noticable relationship between latitude and cloudiness.  The data indidcates that the cloudiness can occur
# high or low at any latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, WindSpeed,edgecolors="black", linewidths=1,marker="o", alpha=0.8, label = "Cities")
plt.title("City Latitude vs Wind Speed (%s)" % time.strftime("%x")) # add current data to chart
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")
plt.grid(True)

#Save graph as a png
plt.savefig("Weatherpy/output_data/city_latitude_vs_windspeed.png")

#show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#create a function to create linear regession plots 
def plot_linear_regression(x_values, y_values,title, text_coordinates):
    #run regression 
    (slope, intercept,rvalue, pvalues,stderr) = linregress(x_values,y_values)
    regress_values=x_values * slope + intercept
    line_eq = "y =" + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    # plot values
    plt.scatter(x_values, y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel (title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
#create northern and southern Hemisphere data fromes
northernHemiDF = clean_city_data.loc[(clean_city_data["Lat"]>=0)]
southernHemiDF = clean_city_data.loc[(clean_city_data["Lat"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northernHemiDF["Lat"]
y_values = northernHemiDF["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(10,40))
# Out:
# The r-value is: 0.456059531606888

# %% [markdown]
# The r-value of 0.45 indicates that there is a weak correlation bweteen max tempatures and latitude in the northern hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southernHemiDF["Lat"]
y_values = southernHemiDF["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(-50,70))
# Out:
# The r-value is: 0.5833824330655276

# %% [markdown]
# The r-value of 0.58 indicates that there is a moderate correlation between the latitude and max tempatures in the Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northernHemiDF["Lat"]
y_values = northernHemiDF["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(0,5))
# Out:
# The r-value is: 0.00926852354263675

# %% [markdown]
# The r-value of 0.009 indicates that there no correlation between latitude and humdity in the Northern Hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southernHemiDF["Lat"]
y_values = southernHemiDF["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(-50,20))
# Out:
# The r-value is: 0.001598855081355867

# %% [markdown]
# The r-value of 0.0015 indicates that there is also no correlation between latitude and humdity in the Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northernHemiDF["Lat"]
y_values = northernHemiDF["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(-1,35))
# Out:
# The r-value is: 0.00022282016688441008

# %% [markdown]
# The r-value of 0.002 indicates that there is no correlation between cloudiness and latitude

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southernHemiDF["Lat"]
y_values = southernHemiDF["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(-50,60))
# Out:
# The r-value is: 0.026974988539828833

# %% [markdown]
# The r-value of 0.02 indicates that there is a very weak correlation between Cloudiness and latitude

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northernHemiDF["Lat"]
y_values = northernHemiDF["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(0,28))
# Out:
# The r-value is: 0.006394575059519185

# %% [markdown]
# The r-value of 0.006 indicates there is a very weak or no correlation between wind speed and latitude in the northern hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southernHemiDF["Lat"]
y_values = southernHemiDF["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(-50,20))
# Out:
# The r-value is: 0.10505191163718626

# %% [markdown]
# The r-value of 0.10 indicates that there is none or very weak correlation between wind speed and latitude in the southern hemisphere
